# %%
import os
import pandas as pd

# %%
# setup file location and paths for the 2 csv files
path = r'C:\Users\Eric\Desktop\School\CS689\wk3'

ship = 'ShipLogbookID'
ship_file = os.path.join(path, ship + '.csv')

trip = 'CLIWOC15'
trip_file = os.path.join(path, trip + '.csv')

# %%
# read csv files into dataframes
ship_df = pd.read_csv(ship_file)
trip_df = pd.read_csv(trip_file)
# Out:
# C:\Users\Eric\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (5,6,7,8,11,13,18,19,23,24,25,26,28,29,30,34,35,38,43,44,46,73,77,81,82,84,85,87,88,94,96,97,98,99,111,114,116,119,120,122,124,125,127,129,131,133,135,137,140) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# shape of the ship dataframe is 1873 rows and 4 columns
print(str(ship_df.shape[0]) + " rows and " + str(ship_df.shape[1]) + " columns.")
# Out:
# 1873 rows and 4 columns.

# %%
# shape of the trip dataframe is 280280 rows and 141 columns
print(str(trip_df.shape[0]) + " rows and " + str(trip_df.shape[1]) + " columns.")
# Out:
# 280280 rows and 141 columns.

# %%
# drop duplicates contained in the shipName and LogBookIdent columns, keeping the first row 
# and writing the result back to the same dataframe
ship_df.drop_duplicates(subset=['ShipName', 'LogbookIdent'], keep='first', inplace=True)

# %%
# shape of the ship dataframe is 1852 rows and 4 columns
ship_df.shape
# Out:
# (1852, 4)

# %%
# crete a left merged dataframe between trip and ship datafrmaes on the 
# ShipName and LogbookIdent columns
joined_set = trip_df.merge(ship_df, how='left', on=['ShipName', 'LogbookIdent'], indicator=True)

# %%
# output the new dataframe
joined_set.head()
# Out:
#    RecID InstAbbr                    InstName InstPlace InstLand NumberEntry  \
# 0    108      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 1    109      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 2    110      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 3    111      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
# 4    112      MNM  Archivo Museo Naval Madrid    Madrid    Spain         NaN
#
#   NameArchiveSet ArchivePart Specification     LogbookIdent  ... Biology  \
# 0            NaN         NaN           NaN  MS. 271, doc 15  ...       0
# 1            NaN         NaN           NaN  MS. 271, doc 16  ...       0
# 2            NaN         NaN           NaN  MS. 271, doc 16  ...       0
# 3            NaN         NaN           NaN  MS. 271, doc 16  ...       0
# 4            NaN         NaN           NaN  MS. 271, doc 16  ...       0
#
#   BiologyMemo  WarsAndFights WarsAndFightsMemo Illustrations  \
# 0         NaN              0               NaN             0
# 1         NaN              0               NaN             0
# 2         NaN              0               NaN             0
# 3         NaN              0               NaN             0
# 4         NaN              0               NaN             0
#
#   TrivialCorrection                                           OtherRem  \
# 0                 0  LA FRAGATA BRETAÑA, DESPUES DE HABER CORRIDO U...
# 1                 0  TODOS FONDEADOS SE DEDICAN A PONER UNA BATERIA...
# 2                 0  TODOS FONDEADOS SE DEDICAN A PONER UNA BATERIA...
# 3                 0  TODOS FONDEADOS SE DEDICAN A PONER UNA BATERIA...
# 4                 0  TODOS FONDEADOS SE DEDICAN A PONER UNA BATERIA...
#
#        ID Duplicate_y _merge
# 0   936.0         0.0   both
# 1  1446.0         0.0   both
# 2  1446.0         0.0   both
# 3  1446.0         0.0   both
# 4  1446.0         0.0   both
#
# [5 rows x 144 columns]

# %%
# filters the joined_set where the merge column equals left_only
joined_set['_merge']=='left_only'

# combines that filter and selects only the shipName column from the joined_set DF
newkeys = joined_set[joined_set['_merge']=='left_only'][['ShipName']]

# drops dupes from the newkeys dataset
newkeys.drop_duplicates(subset=['ShipName'], keep='first', inplace=True)

# outputs newkeys shape, 46 rows 1 column
#newkeys
newkeys.shape
# Out:
# (46, 1)

# %%
# appends the newkeys back to the ship_df 
# sort set to avoid functionality change warning
ship_df = ship_df.append(newkeys, ignore_index=True, sort=True)
ship_df
# Out:
#       Duplicate   ID       LogbookIdent     ShipName
# 0           0.0  1.0    MAR_D23905_1164  Abel Tasman
# 1           0.0  2.0  NMM RUSI/NM/180/6       Acasta
# 2           0.0  3.0  NMM RUSI/NM/180/9       Acasta
# 3           0.0  4.0      NMM ADM/L/A17       Active
# 4           0.0  5.0      NMM ADM/L/A19       Active
# ...         ...  ...                ...          ...
# 1893        NaN  NaN                NaN        Bromo
# 1894        NaN  NaN                NaN    Estafette
# 1895        NaN  NaN                NaN     Cornelia
# 1896        NaN  NaN                NaN  L'hipocrite
# 1897        NaN  NaN                NaN    Amsterdam
#
# [1898 rows x 4 columns]

# %%
# stores ship names and ShipType from trip_df
ShipTypeInfo = trip_df.loc[:,['ShipName','ShipType']]

# drops duplicates based on shipName
ShipTypeInfo.drop_duplicates(subset=['ShipName'], keep= 'first', inplace=True)

# stores ship names and nationality from trip_df
NationalityInfo = trip_df.loc[:,['ShipName','Nationality']]

# drops duplicates based on shipName
NationalityInfo.drop_duplicates(subset=['ShipName'], keep= 'first', inplace=True)

# %%
# merges nationality info back to ship_df based on shipName
ship_df['ShipType']=ship_df.merge(ShipTypeInfo, on=['ShipName'], how='left', indicator=True)['ShipType']

# merges nationality info back to ship_df based on shipName
ship_df['Nationality']=ship_df.merge(NationalityInfo, on=['ShipName'], how='left', indicator=True)['Nationality']

# %%
ship_df.iloc[0:21,:]
# Out:
#     Duplicate    ID                    LogbookIdent               ShipName  \
# 0         0.0   1.0                 MAR_D23905_1164            Abel Tasman
# 1         0.0   2.0               NMM RUSI/NM/180/6                 Acasta
# 2         0.0   3.0               NMM RUSI/NM/180/9                 Acasta
# 3         0.0   4.0                   NMM ADM/L/A17                 Active
# 4         0.0   5.0                   NMM ADM/L/A19                 Active
# 5         0.0   6.0                   NMM ADM/L/A22                Adamant
# 6         0.0   7.0                   NMM ADM/L/A23                Adamant
# 7         0.0   8.0                   MAR_D23905_20                  Adder
# 8         0.0   9.0                   VOC_152_11420     Admiraal de Ruyter
# 9         0.0  10.0                  A2419(1)_1-300      Admiraal Evertsen
# 10        0.0  11.0  Extract P, Reis 9a, pp 110-118  Admiraal Jan Evertsen
# 11        0.0  12.0  Extract P, Reis 9d, pp 138-145  Admiraal Jan Evertsen
# 12        0.0  13.0  Extract P, Reis 9e, pp 147-154  Admiraal Jan Evertsen
# 13        0.0  14.0  Extract P, Reis 9f, pp 155-162  Admiraal Jan Evertsen
# 14        0.0  15.0  Extract P, Reis 9g, pp 164-172  Admiraal Jan Evertsen
# 15        0.0  16.0                 BL L/MAR/B/498B         Admiral Pocock
# 16        0.0  17.0                 BL L/MAR/B/498G         Admiral Pocock
# 17        0.0  18.0                 BL L/MAR/B/623C         Admiral Vernon
# 18        0.0  19.0                    VOC_152_5055                 Africa
# 19        0.0  20.0                      MCC_20_204     Africaensche Galey
# 20        0.0  21.0                       GAD_156_1                 Agatha
#
#     ShipType Nationality
# 0        NaN       Dutch
# 1   5th Rate     British
# 2   5th Rate     British
# 3   5th rate     British
# 4   5th rate     British
# 5   4th rate     British
# 6   4th rate     British
# 7   Schoener       Dutch
# 8        NaN       Dutch
# 9        NaN       Dutch
# 10       NaN       Dutch
# 11       NaN       Dutch
# 12       NaN       Dutch
# 13       NaN       Dutch
# 14       NaN       Dutch
# 15       NaN     British
# 16       NaN     British
# 17       NaN     British
# 18       NaN       Dutch
# 19       NaN       Dutch
# 20       NaN       Dutch

# %%
# store the selected columns into new dataframe called TripMeasures
TripMeasures = trip_df[['ShipName','LogbookIdent','RecID','Rain','Fog','Snow','Thunder','Year','Month','Day']]

TripMeasures.iloc[0:21,:]
# Out:
#           ShipName     LogbookIdent  RecID  Rain  Fog  Snow  Thunder  Year  \
# 0          LA ORBE  MS. 271, doc 15    108     0    0     0        0  1800
# 1       SAN CARLOS  MS. 271, doc 16    109     0    0     0        0  1790
# 2       SAN CARLOS  MS. 271, doc 16    110     0    0     0        0  1790
# 3       SAN CARLOS  MS. 271, doc 16    111     0    0     0        0  1790
# 4       SAN CARLOS  MS. 271, doc 16    112     0    0     0        0  1790
# 5       SAN CARLOS  MS. 271, doc 16    113     0    0     0        0  1790
# 6          LA ORBE  MS. 271, doc 15    114     0    0     0        0  1800
# 7          LA ORBE  MS. 271, doc 15    115     1    0     0        0  1800
# 8          LA ORBE  MS. 271, doc 15    116     1    0     0        0  1800
# 9          LA ORBE  MS. 271, doc 15    117     1    0     0        0  1800
# 10         LA ORBE  MS. 271, doc 15    118     0    0     0        0  1800
# 11         LA ORBE  MS. 271, doc 15    119     0    0     0        0  1800
# 12  SANTA PERPETUA          MS. 204    120     0    0     0        0  1774
# 13  SANTA PERPETUA          MS. 204    121     0    0     0        0  1774
# 14  SANTA PERPETUA          MS. 204    122     0    0     0        0  1774
# 15  SANTA PERPETUA          MS. 204    123     0    0     0        0  1774
# 16  SANTA PERPETUA          MS. 204    124     0    0     0        0  1774
# 17  SANTA PERPETUA          MS. 204    125     0    0     0        0  1774
# 18  SANTA PERPETUA          MS. 204    126     0    0     0        0  1774
# 19  SANTA PERPETUA          MS. 204    127     0    0     0        0  1774
# 20  SANTA PERPETUA          MS. 204    128     0    0     0        0  1774
#
#     Month  Day
# 0       5    2
# 1       4   11
# 2       4   12
# 3       4   13
# 4       4   14
# 5       4   15
# 6       3   31
# 7       4    1
# 8       4    2
# 9       4    3
# 10      4    4
# 11      4    5
# 12      3   13
# 13      3   14
# 14      3   15
# 15      3   16
# 16      3   17
# 17      3   18
# 18      3   19
# 19      3   20
# 20      3   21

# %%
# created a date column containing all 0's
TripMeasures.loc[:,'Date'] = 0

# filled the date column with pandas to_datetime using the year, month, day columns from trip measures
TripMeasures.loc[:,'Date'] = pd.to_datetime(TripMeasures.loc[:,['Year','Month','Day']], errors='coerce')

TripMeasures.iloc[0:21,:]
# Out:
# C:\Users\Eric\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:376: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\Eric\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:494: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
#           ShipName     LogbookIdent  RecID  Rain  Fog  Snow  Thunder  Year  \
# 0          LA ORBE  MS. 271, doc 15    108     0    0     0        0  1800
# 1       SAN CARLOS  MS. 271, doc 16    109     0    0     0        0  1790
# 2       SAN CARLOS  MS. 271, doc 16    110     0    0     0        0  1790
# 3       SAN CARLOS  MS. 271, doc 16    111     0    0     0        0  1790
# 4       SAN CARLOS  MS. 271, doc 16    112     0    0     0        0  1790
# 5       SAN CARLOS  MS. 271, doc 16    113     0    0     0        0  1790
# 6          LA ORBE  MS. 271, doc 15    114     0    0     0        0  1800
# 7          LA ORBE  MS. 271, doc 15    115     1    0     0        0  1800
# 8          LA ORBE  MS. 271, doc 15    116     1    0     0        0  1800
# 9          LA ORBE  MS. 271, doc 15    117     1    0     0        0  1800
# 10         LA ORBE  MS. 271, doc 15    118     0    0     0        0  1800
# 11         LA ORBE  MS. 271, doc 15    119     0    0     0        0  1800
# 12  SANTA PERPETUA          MS. 204    120     0    0     0        0  1774
# 13  SANTA PERPETUA          MS. 204    121     0    0     0        0  1774
# 14  SANTA PERPETUA          MS. 204    122     0    0     0        0  1774
# 15  SANTA PERPETUA          MS. 204    123     0    0     0        0  1774
# 16  SANTA PERPETUA          MS. 204    124     0    0     0        0  1774
# 17  SANTA PERPETUA          MS. 204    125     0    0     0        0  1774
# 18  SANTA PERPETUA          MS. 204    126     0    0     0        0  1774
# 19  SANTA PERPETUA          MS. 204    127     0    0     0        0  1774
# 20  SANTA PERPETUA          MS. 204    128     0    0     0        0  1774
#
#     Month  Day       Date
# 0       5    2 1800-05-02
# 1       4   11 1790-04-11
# 2       4   12 1790-04-12
# 3       4   13 1790-04-13
# 4       4   14 1790-04-14
# 5       4   15 1790-04-15
# 6       3   31 1800-03-31
# 7       4    1 1800-04-01
# 8       4    2 1800-04-02
# 9       4    3 1800-04-03
# 10      4    4 1800-04-04
# 11      4    5 1800-04-05
# 12      3   13 1774-03-13
# 13      3   14 1774-03-14
# 14      3   15 1774-03-15
# 15      3   16 1774-03-16
# 16      3   17 1774-03-17
# 17      3   18 1774-03-18
# 18      3   19 1774-03-19
# 19      3   20 1774-03-20
# 20      3   21 1774-03-21

# %%
# replace all NaN with an empty string
ship_df.fillna('', inplace=True)

# %%
for i,row in ship_df.iterrows():
    ship_df.at[i, "LogbookIdent"] = row.LogbookIdent.replace("'", "''")
    ship_df.at[i, "ShipName"] = row.ShipName.replace("'", "''")
    ship_df.at[i, "ShipType"] = row.ShipType.replace("'", "''")
    ship_df.at[i, "Nationality"] = row.Nationality.replace("'", "''")

# %%
# replace all NaN with an empty string
TripMeasures.fillna('', inplace=True)
# Out:
# C:\Users\Eric\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:4244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   **kwargs

# %%
# setup connection to the SQL server
import pyodbc
conn = pyodbc.connect('Driver={SQL Server};'
                     'Server=DESKTOP-J0OJSOF;'
                     'Database=ship;'
                     'Trusted_Connection=yes;')
cursor = conn.cursor();

# %%
# iterates through ship_df and inserts the LogbookIdent, ShipName, ShipType and Nationality into the ship db dim_ship table
for i,row in ship_df.iterrows():
    sql = "INSERT INTO ship.dbo.Dim_Ship(LogbookIdent, ShipName, ShipType, Nationality) VALUES(" +"'"+ str(row.LogbookIdent) + "', '" + str(row.ShipName) + "', '" + str(row.ShipType) + "', '" + str(row.Nationality) +"');"  
    cursor.execute(sql)

# %%
conn.commit()

# %%
# iterates through TripMeasures and inserts the RecID, Date, Rain, Fog, Snow and Thunder into the ship db Fact_Trip table
for i,row in TripMeasures.iterrows():
    sql = "INSERT INTO ship.dbo.Fact_Trip(RecID, Date, Rain, Fog, Snow, Thunder) VALUES(" +"'"+ str(row.RecID) + "', '" + str(row.Date) + "', '" + str(row.Rain) + "', '" + str(row.Fog) + "', '" + str(row.Snow) + "', '" + str(row.Thunder) +"');"  
    cursor.execute(sql)

# %%
conn.commit()

# %%
# Regex
ship_df['LogbookIdent'].replace(to_replace=r'^\w\s', value='', regex = True, inplace = True)

# %%
ship_df['LogbookIdent']
# Out:
# 0         MAR_D23905_1164
# 1       NMM RUSI/NM/180/6
# 2       NMM RUSI/NM/180/9
# 3           NMM ADM/L/A17
# 4           NMM ADM/L/A19
#               ...
# 1893
# 1894
# 1895
# 1896
# 1897
# Name: LogbookIdent, Length: 1898, dtype: object
