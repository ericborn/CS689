# %% [markdown]
# # ClickStream - Getting Started - Explorations

# %% [markdown]
# This post gives an introduction to working with the [Wikipedia Clickstream](http://figshare.com/articles/Wikipedia_Clickstream/1305770) dataset. It shows how people get to a Wikipedia article and what articles they click on next. In other words, it gives a weighted network of articles, where each edge weight corresponds to how often people navigate from one page to another. To give an example, consider the figure below, which shows incoming and outgoing traffic to the "London" article.

# %%
from IPython.display import IFrame
IFrame('London_Sankey.html', width=950, height=450)
# Out:
#         <iframe
#             width="950"
#             height="450"
#             src="London_Sankey.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# The example shows that most people found the "London" page through Google Search and that only a small fraction of readers went on to another article. Before diving into some examples of working with the data, let me give a more detailed explanation of how the data was collected.

# %% [markdown]
# ### Data Preparation
#
# The data contains counts of (referer, resource) pairs extracted from the request logs of English Wikipedia. When a client requests a resource by following a link or performing a search, the URI of the webpage that linked to the resource is included with the request in an HTTP header called the "referer". This data captures 22 million (referer, resource) pairs from a total of 3.2 billion requests collected during the month of February 2015.
#
# The dataset only includes requests for articles in the [main namespace](https://en.wikipedia.org/wiki/Wikipedia:Namespace) of the desktop version of English Wikipedia.
#
# Referers were [mapped](https://github.com/ewulczyn/wmf/blob/f76d43eee9e3e9756cd6a062a11e382fd4425edf/clickstream/oozie/hive_query.sql#L152-L203) to a fixed set of values corresponding to internal traffic or external traffic from one of the top 5 global traffic sources to English Wikipedia, based on this scheme:
#     - an article in the main namespace of English Wikipedia -> the article title
#     - any Wikipedia page that is not in the main namespace of English Wikipedia -> `other-wikipedia`
#     - an empty referer -> `other-empty`
#     - a page from any other Wikimedia project -> `other-internal`
#     - Google -> `other-google`
#     - Yahoo -> `other-yahoo`
#     - Bing -> `other-bing`
#     - Facebook -> `other-facebook`
#     - Twitter -> `other-twitter`
#     - anything else -> `other-other`
#
#
# MediaWiki Redirects are used to forward clients from one page name to another. They can be useful if a particular article is referred to by multiple names, or has alternative punctuation, capitalization or spellings. Requests for pages that get redirected where mapped to the page they redirect to. For example, requests for 'Obama' redirect to the 'Barack_Obama' page. Redirects where resolved using a snapshot of the redirects table from March 1 2015.
#
# Redlinks are are links to an article that does not exist. Either the article was deleted after the creation of the link or the author intended to signal the need for such an article. Requests for redlinks are included in the data.
#
# We attempt to exclude spider traffic by classifying user agents with the [ua-parser](https://github.com/tobie/ua-parser) library and a few additonal Wikipedia specific filters. Furthermore, we attempt to filter out traffic from bots that request a page and then request all or most of the links on that page (BFS traversal) by setting a threshold on the rate at which a client can requests articles with the same referer. Requests that where made at too high of a rate get discarded. For the exact details, see [here](https://github.com/ewulczyn/wmf/blob/f76d43eee9e3e9756cd6a062a11e382fd4425edf/clickstream/oozie/throttle.py). The threshold is quite high to avoid excluding human readers who open tabs as they read. As a result requests from slow moving bots are likely to remain in the data. More sophisticated bot detection, that evaluates the clients entire request graph is an avenue of future work.
#
# Finally, any `(referer, resource)` pair with 10 or fewer observations was removed from the dataset.
#
#
# ### Format
# The data includes the following 6 fields:
#
# - **prev_id:** if the referer does not correspond to an article in the main namespace of English Wikipedia, this value will be empty. Otherwise, it contains the unique MediaWiki page ID of the article corresponding to the referer i.e. the previous article the client was on
# - **curr_id:** the MediaWiki unique page ID of the article the client requested
# - **n:** the number of occurrences of the `(referer, resource)` pair
# - **prev_title:** the result of mapping the referer URL to the fixed set of values described above
# - **curr_title:** the title of the article the client requested
# - **type**
# - "link" if the referer and request are both articles and the referer links to the request
#     - "redlink" if the referer is an article and links to the request, but the request is not in the produiction enwiki.page table
#     - "other" if the referer and request are both articles but the referer does not link to the request. This can happen when clients search or spoof their refer

# %% [markdown]
# # Getting to know the Data
#
# There are various quirks in the data due to the dynamic nature of the network of articles in English Wikipedia and the prevalence of requests from automata. The following section gives a brief overview of the data fields and caveats that need to be kept in mind.

# %% [markdown]
# ### Loading the Data
# First, let's load the data into a pandas DataFrame.
#
# You will need to download 2015_02_filtered_en_clickstream.tsv into the same directory as this Python file.

# %%
import pandas as pd
df = pd.read_csv("2015_02_filtered_en_clickstream.tsv", sep='\t', header=0)

# %%
#we won't use ids here, so lets discard them
df = df[['prev_title', 'curr_title', 'n', 'type']]
df.columns = ['prev', 'curr', 'n', 'type']

# %%
df.columns
# Out:
# Index(['prev', 'curr', 'n', 'type'], dtype='object')

# %% [markdown]
# ### Top articles
# It has been possible to estimate which pages get the most pageviews per month from the public pageview dumps that WMF releases.

# %%
df.groupby('curr').sum().sort_values('n', ascending=False)[:15]
# Out:
#                                             n
# curr
# 87th_Academy_Awards                   2559794
# Fifty_Shades_of_Grey                  2326175
# Alive                                 2244781
# Chris_Kyle                            1709341
# Fifty_Shades_of_Grey_(film)           1683892
# Deaths_in_2015                        1614577
# Birdman_(film)                        1545842
# Islamic_State_of_Iraq_and_the_Levant  1406530
# Stephen_Hawking                       1384193
# Academy_Awards                        1354794
# Better_Call_Saul                      1338538
# Alessandro_Volta                      1228952
# Dakota_Johnson                        1082101
# The_Flash_(2014_TV_series)            1060815
# Valentine's_Day                       1046976

# %%
view25 = df.groupby('curr').sum().sort_values('n', ascending=False)[24:25].index.values[0]

view25
# Out:
# 'Jamie_Dornan'

# %% [markdown]
# The most requested pages tend to be about media that was popular in April.

# %% [markdown]
# ### Top Referers
# The clickstream data aslo lets us investigate who the top referers to Wikipedia are:

# %%
df.groupby('prev').sum().sort_values('n', ascending=False)[:15]
# Out:
#                                      n
# prev
# other-google                  16079189
# other-empty                    4258173
# other-wikipedia                3391566
# other-facebook                 2314026
# 87th_Academy_Awards            1680675
# Main_Page                      1573391
# Fifty_Shades_of_Grey_(film)    1375687
# Fifty_Shades_of_Grey           1146401
# Deaths_in_2015                 1135121
# 2015_in_film                   1049042
# Chris_Kyle                      869974
# The_Walking_Dead_(TV_series)    849466
# Better_Call_Saul                823712
# Birdman_(film)                  796141
# other-yahoo                     795063

# %%
refers16 = df.groupby('prev').sum().sort_values('n', ascending=False)[15:16].index.values[0]

refers16
# Out:
# 'Islamic_State_of_Iraq_and_the_Levant'

# %% [markdown]
# The top referer by a large margin is Google. Next comes refererless traffic (usually clients using HTTPS). Then come other language Wikipedias and pages in English Wikipedia that are not in the main (i.e. article) namespace. Bing directs significanlty more traffic to Wikipedia than Yahoo. Social media referals are tiny compared to Google, with twitter leading to 10x more requests to Wikipedia than Facebook.

# %% [markdown]
# ### Trending on Social Media
# Lets look at what articles where trending on Twitter:

# %%
df_twitter = df[df['prev'] == 'other-twitter']
df_twitter.groupby('curr').sum().sort_values('n', ascending=False)[:5]
# Out:
#                                           n
# curr
# Facebook                              30624
# Fifty_Shades_of_Grey                   4950
# Chinese_New_Year                       4170
# Fifty_Shades_of_Grey_(film)            2650
# Islamic_State_of_Iraq_and_the_Levant   1906

# %%
trend7 = df_twitter.groupby('curr').sum().sort_values('n', ascending=False)[5:6].index.values[0]

trend7
# Out:
# "Stayin'_Alive"

# %% [markdown]
# I'm have no explanations for this, but if you find any of the tweets linking to these article, I would be curious to see why they got so many click throughs.

# %% [markdown]
# ### Most Requested Missing Pages
# Next lets look at the most popular redinks. Redlinks are links to a Wikipedia page that does not exist, either because it has been deleted, or because the author is anticipating the creation of the page. Seeing which redlinks are the most viewed is interesting because it gives some indication about demand for missing content. Since the set of pages and links is constantly changing, the labeling of redlinks is not an exact science. In this case, I used the page and links tables from Feb 28th to mark a page as a redlink.

# %%
df_redlinks = df[df['type'] == 'redlink']
df_redlinks.groupby('curr').sum().sort_values('n', ascending=False)[:5]
# Out:
#                           n
# curr
# Ben_Woolf              2764
# June_Fairchild         1485
# Tim_Ford_(politician)   480
# Bobby_Emmons            414
# John_Crocker_(actor)    379

# %%
df_redlinks[df_redlinks['prev'] == refers16]
# Out:
#                                        prev  \
# 6309   Islamic_State_of_Iraq_and_the_Levant
# 19114  Islamic_State_of_Iraq_and_the_Levant
# 35732  Islamic_State_of_Iraq_and_the_Levant
# 37090  Islamic_State_of_Iraq_and_the_Levant
# 37539  Islamic_State_of_Iraq_and_the_Levant
# 46135  Islamic_State_of_Iraq_and_the_Levant
# 50633  Islamic_State_of_Iraq_and_the_Levant
# 87826  Islamic_State_of_Iraq_and_the_Levant
#
#                                            curr   n     type
# 6309                                       BNPT  41  redlink
# 19114                          Hafiz_Saeed_Khan  76  redlink
# 35732  Roméo_Dallaire_Child_Soldiers_Initiative  58  redlink
# 37090                            Shabak_Militia  68  redlink
# 37539                      Sinjar_Defence_Force  13  redlink
# 46135               Yekîneyên_Berxwedana_Şingal  13  redlink
# 50633                 Abu_Salim_Martyrs_Brigade  20  redlink
# 87826                   Sinjar_Resistance_Units  27  redlink

# %%
df[(df['prev'] == refers16) & (df['type'] == 'redlink')]
# Out:
#                                        prev  \
# 6309   Islamic_State_of_Iraq_and_the_Levant
# 19114  Islamic_State_of_Iraq_and_the_Levant
# 35732  Islamic_State_of_Iraq_and_the_Levant
# 37090  Islamic_State_of_Iraq_and_the_Levant
# 37539  Islamic_State_of_Iraq_and_the_Levant
# 46135  Islamic_State_of_Iraq_and_the_Levant
# 50633  Islamic_State_of_Iraq_and_the_Levant
# 87826  Islamic_State_of_Iraq_and_the_Levant
#
#                                            curr   n     type
# 6309                                       BNPT  41  redlink
# 19114                          Hafiz_Saeed_Khan  76  redlink
# 35732  Roméo_Dallaire_Child_Soldiers_Initiative  58  redlink
# 37090                            Shabak_Militia  68  redlink
# 37539                      Sinjar_Defence_Force  13  redlink
# 46135               Yekîneyên_Berxwedana_Şingal  13  redlink
# 50633                 Abu_Salim_Martyrs_Brigade  20  redlink
# 87826                   Sinjar_Resistance_Units  27  redlink

# %% [markdown]
# ### Searching Within Wikipedia

# %% [markdown]
#  Usually, clients navigate from one article to another through follwing a link. The other prominent case is search. The article from which the user searched is also passed as the referer to the found article. Hence, you will find a high count of `(Wikipedia, Chris_Kyle)` tuples. People went to the "Wikipedia" article to search for "Chris_Kyle". There is not a link to the "Chris_Kyle" article from the "Wikipedia" article. Finally, it is possible that the client messed with their referer header. The vast majority of requests with an internal referer correspond to a true link.

# %%
df_search = df[df['type'] == 'other']
df_search = df_search[df_search.prev.str.match("^other.*").apply(bool) == False]

df_search

print ("Number of searches/ incorrect referers: %d" % df_search.n.sum())
# Out:
# Number of searches/ incorrect referers: 1656796

# %%
df_link = df[df['type'] == 'link']
df_link =  df_link[df_link.prev.str.match("^other.*").apply(bool) == False]
print ("Number of links followed: %d" % df_link.n.sum())
# Out:
# Number of links followed: 19947182

# %% [markdown]
# ### Inflow vs Outflow

# %% [markdown]
# You might be tempted to think that there can't be more traffic going out of a node than going into a node. This is not true for two reasons. People will follow links in multiple tabs as they read an article. Hence, a single pageview can lead to multiple records with that page as the referer. The data is also certain to include requests from bots which we did not correctly filter out. Bots will often follow most if not all the links in the article. Lets look at the ratio of incoming to outgoing links for the most requested pages.

# %%
df_in = df.groupby('curr').sum()  # pageviews per article
df_in.columns = ['in_count',]
df_out = df.groupby('prev').sum() # link clicks per article
df_out.columns = ['out_count',]
df_in_out = df_in.join(df_out)
df_in_out['ratio'] = df_in_out['out_count']/df_in_out['in_count'] #compute ratio if outflow/infow

# %%
df_in_out.sort_values('in_count', ascending = False)[:3]
# Out:
#                       in_count  out_count     ratio
# curr
# 87th_Academy_Awards    2559794  1680675.0  0.656567
# Fifty_Shades_of_Grey   2326175  1146401.0  0.492827
# Alive                  2244781     3480.0  0.001550

# %% [markdown]
# Looking at the pages with the highest ratio of outgoing to incoming traffic reveals how messy the data is, even after the carefull data preparation described above.

# %%
df_in_out.sort_values('ratio', ascending = False)[:3]
# Out:
#                                                     in_count  out_count  \
# curr
# Lists_of_films                                            13     8077.0
# Nimoy                                                     21     4913.0
# List_of_awards_and_nominations_received_by_Juli...        15     3306.0
#
#                                                          ratio
# curr
# Lists_of_films                                      621.307692
# Nimoy                                               233.952381
# List_of_awards_and_nominations_received_by_Juli...  220.400000

# %%
df_in_out.sort_values('in_count', ascending = False)[8:9]
# Out:
#                  in_count  out_count     ratio
# curr
# Stephen_Hawking   1384193   644088.0  0.465317

# %%
df_in_out.sort_values('ratio', ascending = False)[7:8]
# Out:
#                         in_count  out_count       ratio
# curr
# The_Weeknd_discography        11     1333.0  121.181818

# %% [markdown]
# ### Filtering Traversals

# %% [markdown]
# All of these pages have more traversals of a single link than they have requests for the page to begin with.  As a post processing step, we might enforce that there can't be more traversals of a link than there where requests to the page. Better bot filtering should help reduce this issue in the future.

# %%
df_post = pd.merge(df, df_in, how='left', left_on='prev', right_index=True)
df_post['n'] = df_post[['n', 'in_count']].min(axis=1)
del df_post['in_count']

# %%
df_post.head()
# Out:
#                                 prev              curr       n   type
# 0  List_of_Academy_Awards_ceremonies  Crocodile_Dundee    59.0   link
# 1                       2015_in_film  Crocodile_Dundee    66.0   link
# 2                59th_Academy_Awards  Crocodile_Dundee    18.0   link
# 3                     Deaths_in_2015  Crocodile_Dundee  1283.0   link
# 4                     other-facebook     I_AM_Activity    33.0  other

# %%
df_in = df_post.groupby('curr').sum()  # pageviews per article
df_in
df_in.columns = ['in_count',]
df_out = df_post.groupby('prev').sum() # link clicks per article
df_out.columns = ['out_count',]
df_in_out = df_in.join(df_out)
df_in_out['ratio'] = df_in_out['out_count']/df_in_out['in_count']

# %%
df_in_out.sort_values('ratio', ascending = False)[:5]
# Out:
#                                                     in_count  out_count  \
# curr
# Wiki                                                    36.0      790.0
# Wikipedia                                              318.0     4740.0
# List_of_awards_and_nominations_received_by_Mery...      80.0      797.0
# Main_Page                                            89834.0   793392.0
# February_2015                                           15.0      101.0
#
#                                                         ratio
# curr
# Wiki                                                21.944444
# Wikipedia                                           14.905660
# List_of_awards_and_nominations_received_by_Mery...   9.962500
# Main_Page                                            8.831756
# February_2015                                        6.733333

# %% [markdown]
# ### What is this code doing (#1)?

# %%
df_norm = pd.merge(df_post, df_out, how='left', left_on='prev', right_index=True)

# %%
df_norm = df_norm.sort_values(['prev', 'curr'])

# %%
df_norm['w'] = df_norm['n'] / df_norm['out_count']

# %%
df_norm.head(40)
# Out:
#                           prev                                        curr  \
# 57171                       %s                              Birdman_(film)
# 8518                        %s                                Bruce_Jenner
# 59721                       %s                                  Chris_Kyle
# 65189                       %s                        Fifty_Shades_of_Grey
# 65915                       %s                 Fifty_Shades_of_Grey_(film)
# 25048                       %s                               Leonard_Nimoy
# 89314                       %s                             Stephen_Hawking
# 57112               '71_(film)                              Birdman_(film)
# 4283             '99–'00_Demos                                   Alive_'05
# 11244            'It's_Alive!'                     Creature_of_Destruction
# 53686         ...Is_a_Real_Boy                Alive_with_the_Glory_of_Love
# 59702   .300_Winchester_Magnum                                  Chris_Kyle
# 59700        .338_Lapua_Magnum                                  Chris_Kyle
# 71748                      .is        Islamic_State_of_Iraq_and_the_Levant
# 15349                      .me                                    Facebook
# 65221       1000_Forms_of_Fear                        Fifty_Shades_of_Grey
# 65852       1000_Forms_of_Fear                 Fifty_Shades_of_Grey_(film)
# 66043       1000_Forms_of_Fear           Fifty_Shades_of_Grey_(soundtrack)
# 89239     100_Greatest_Britons                             Stephen_Hawking
# 42352             100_episodes                The_Walking_Dead_(TV_series)
# 59701  101st_Airborne_Division                                  Chris_Kyle
# 94594  101st_Airborne_Division                 Valentine's_Day_(2010_film)
# 79         10th_Academy_Awards                         11th_Academy_Awards
# 46566      10th_Academy_Awards                         12th_Academy_Awards
# 466        10th_Academy_Awards                          1st_Academy_Awards
# 50085      10th_Academy_Awards                         87th_Academy_Awards
# 50296      10th_Academy_Awards                          9th_Academy_Awards
# 2977       10th_Academy_Awards                 A_Damsel_in_Distress_(film)
# 3043       10th_Academy_Awards                  A_Star_Is_Born_(1937_film)
# 50740      10th_Academy_Awards  Academy_Award_for_Best_Animated_Short_Film
# 3397       10th_Academy_Awards              Academy_Award_for_Best_Picture
# 53305      10th_Academy_Awards                                 Alice_Brady
# 5360       10th_Academy_Awards                      Anne_Shirley_(actress)
# 6575       10th_Academy_Awards                            Barbara_Stanwyck
# 7507       10th_Academy_Awards                         Black_Legion_(film)
# 7756       10th_Academy_Awards                        Bob_Burns_(comedian)
# 58658      10th_Academy_Awards                         Camille_(1936_film)
# 9177       10th_Academy_Awards             Captains_Courageous_(1937_film)
# 9648       10th_Academy_Awards                               Charles_Boyer
# 60645      10th_Academy_Awards                        Conquest_(1937_film)
#
#            n   type  out_count         w
# 57171   13.0  other      119.0  0.109244
# 8518    13.0  other      119.0  0.109244
# 59721   18.0  other      119.0  0.151261
# 65189   20.0  other      119.0  0.168067
# 65915   22.0  other      119.0  0.184874
# 25048   20.0  other      119.0  0.168067
# 89314   13.0  other      119.0  0.109244
# 57112   12.0  other       12.0  1.000000
# 4283    11.0   link       11.0  1.000000
# 11244   13.0   link       13.0  1.000000
# 53686   59.0   link       59.0  1.000000
# 59702   14.0  other       14.0  1.000000
# 59700   20.0  other       20.0  1.000000
# 71748   16.0   link       16.0  1.000000
# 15349   21.0   link       21.0  1.000000
# 65221   11.0  other       33.0  0.333333
# 65852   11.0  other       33.0  0.333333
# 66043   11.0  other       33.0  0.333333
# 89239  388.0   link      388.0  1.000000
# 42352   21.0   link       21.0  1.000000
# 59701   11.0  other       25.0  0.440000
# 94594   14.0   link       25.0  0.560000
# 79     923.0   link     2396.0  0.385225
# 46566   16.0   link     2396.0  0.006678
# 466     10.0   link     2396.0  0.004174
# 50085   10.0   link     2396.0  0.004174
# 50296  339.0   link     2396.0  0.141486
# 2977    16.0   link     2396.0  0.006678
# 3043    72.0   link     2396.0  0.030050
# 50740   11.0   link     2396.0  0.004591
# 3397    11.0   link     2396.0  0.004591
# 53305   25.0   link     2396.0  0.010434
# 5360    11.0   link     2396.0  0.004591
# 6575    10.0   link     2396.0  0.004174
# 7507    13.0   link     2396.0  0.005426
# 7756    34.0   link     2396.0  0.014190
# 58658   13.0   link     2396.0  0.005426
# 9177    52.0   link     2396.0  0.021703
# 9648    15.0   link     2396.0  0.006260
# 60645   16.0   link     2396.0  0.006678

# %% [markdown]
# ### What is this code doing (#2) ?

# %%
node = "Alive"
n=10

# %%
prev
# Out:
#                        prev   curr        n   type
# 53356       other-wikipedia  Alive  2221485  other
# 53343           other-empty  Alive    22109  other
# 53347             Main_Page  Alive      540  other
# 53345                 Alive  Alive      215  other
# 53355          other-google  Alive      140  other
# 53354  LAN_Chile_Flight_210  Alive       98  other
# 53348           other-other  Alive       42  other
# 53357           other-yahoo  Alive       40  other
# 53349            other-bing  Alive       26  other
# 53353                  Live  Alive       23  other

# %%
prev = df[df['curr'] == node].sort_values(by=['n'], ascending=False)[:n]
tuples = [list(x) for x in prev.values]
from pprint import pprint 
pprint(tuples)
# Out:
# [['other-wikipedia', 'Alive', 2221485, 'other'],
#  ['other-empty', 'Alive', 22109, 'other'],
#  ['Main_Page', 'Alive', 540, 'other'],
#  ['Alive', 'Alive', 215, 'other'],
#  ['other-google', 'Alive', 140, 'other'],
#  ['LAN_Chile_Flight_210', 'Alive', 98, 'other'],
#  ['other-other', 'Alive', 42, 'other'],
#  ['other-yahoo', 'Alive', 40, 'other'],
#  ['other-bing', 'Alive', 26, 'other'],
#  ['Live', 'Alive', 23, 'other']]

# %%
prev = df[df['prev'] == node].sort_values(by=['n'], ascending=False)[:n]
tuples = [list(x) for x in prev.values]
from pprint import pprint 
pprint(tuples)
# Out:
# [['Alive', 'Alive_(1993_film)', 1948, 'link'],
#  ['Alive', 'Alive:_The_Story_of_the_Andes_Survivors', 482, 'link'],
#  ['Alive', 'Alive', 215, 'other'],
#  ['Alive', 'Bat_Out_of_Hell_III:_The_Monster_Is_Loose', 202, 'link'],
#  ['Alive', 'Alive:_20_Years_Later', 106, 'link'],
#  ['Alive', 'Alive_(Pearl_Jam_song)', 97, 'link'],
#  ['Alive', 'Alive!_(Kiss_album)', 69, 'link'],
#  ['Alive', 'Life', 68, 'link'],
#  ['Alive', 'Alive_(2002_film)', 51, 'link'],
#  ['Alive', 'Alive_(Natalie_Bassingthwaighte_song)', 48, 'link']]

# %% [markdown]
# # Simple Network Analysis

# %% [markdown]
# We can think of Wikipedia as a network with articles as nodes and links between articles as edges. With the clickstream data we can assign weights to the edges, which correspond to how often the edges where traversed. Remember, that if an edge was traversed less than ten times in the month, it is not included in the data. The data set is on the large side, but with some patience, we can load it into networkx and look at some basic properties of the network.
# *takes five-fifteen seconds...*

# %%
import networkx as nx
clickstream = nx.DiGraph()

for i, row in df_post.iterrows():
    clickstream.add_edge(row['prev'], row['curr'], traffic = row['n'])

# %%
clickstream.number_of_nodes ()
# Out:
# 70022

# %%
[n for n in clickstream.neighbors('10th_Academy_Awards')]
# Out:
# ['11th_Academy_Awards',
#  '1st_Academy_Awards',
#  'A_Damsel_in_Distress_(film)',
#  'A_Star_Is_Born_(1937_film)',
#  'Academy_Award_for_Best_Picture',
#  'Anne_Shirley_(actress)',
#  'Barbara_Stanwyck',
#  'Black_Legion_(film)',
#  'Bob_Burns_(comedian)',
#  'Captains_Courageous_(1937_film)',
#  'Charles_Boyer',
#  'Educated_Fish',
#  'In_Old_Chicago',
#  'Joseph_Schildkraut',
#  'Luise_Rainer',
#  'Paul_Muni',
#  'Penny_Wisdom',
#  'Ralph_Bellamy',
#  'Snow_White_and_the_Seven_Dwarfs_(1937_film)',
#  'Spencer_Tracy',
#  'Stella_Dallas_(1937_film)',
#  'The_Good_Earth_(film)',
#  'The_Hurricane_(1937_film)',
#  'The_Life_of_Emile_Zola',
#  'The_Old_Mill',
#  'The_Prisoner_of_Zenda_(1937_film)',
#  'Torture_Money',
#  'Waikiki_Wedding',
#  'William_A._Wellman',
#  'Wings_over_Honolulu',
#  '12th_Academy_Awards',
#  '87th_Academy_Awards',
#  '9th_Academy_Awards',
#  'Academy_Award_for_Best_Animated_Short_Film',
#  'Alice_Brady',
#  'Camille_(1936_film)',
#  'Conquest_(1937_film)',
#  'Dead_End_(1937_film)',
#  'H._B._Warner',
#  'Janet_Gaynor',
#  'Los_Angeles_flood_of_1938',
#  'Lost_Horizon_(1937_film)',
#  'Night_Must_Fall_(1937_film)',
#  'One_Hundred_Men_and_a_Girl',
#  'Robert_Montgomery_(actor)',
#  'Stage_Door',
#  'Sweet_Leilani',
#  'The_Awful_Truth',
#  'The_Little_Match_Girl',
#  'The_Private_Life_of_the_Gannets']

# %%
[n for n in clickstream.neighbors('Spencer_Tracy')]
# Out:
# ['40th_Academy_Awards', 'Academy_Awards']

# %%
[n for n in clickstream.neighbors('Bette_Davis')]
# Out:
# ['Academy_Awards']

# %%
[n for n in clickstream.neighbors('Academy_Awards')]
# Out:
# ['11th_Academy_Awards',
#  '12_Years_a_Slave_(film)',
#  '13th_Academy_Awards',
#  '15th_Academy_Awards',
#  '17th_Academy_Awards',
#  '1997_Academy_Awards',
#  '19th_Academy_Awards',
#  '1st_Academy_Awards',
#  '2002_Academy_Awards',
#  '2008_Academy_Awards',
#  '2011_Academy_Awards',
#  '2013_Academy_Awards',
#  '2014_in_film',
#  '21st_Academy_Awards',
#  '22nd_Academy_Awards',
#  '24th_Academy_Awards',
#  '26th_Academy_Awards',
#  '28th_Academy_Awards',
#  '2nd_Academy_Awards',
#  '33rd_Academy_Awards',
#  '35_mm_film',
#  '35th_Academy_Awards',
#  '37th_Academy_Awards',
#  '39th_Academy_Awards',
#  '40th_Academy_Awards',
#  '41st_Academy_Awards',
#  '42nd_Academy_Awards',
#  '44th_Academy_Awards',
#  '46th_Academy_Awards',
#  '48th_Academy_Awards',
#  '4th_Academy_Awards',
#  '53rd_Academy_Awards',
#  '55th_Academy_Awards',
#  '57th_Academy_Awards',
#  '59th_Academy_Awards',
#  '60th_Academy_Awards',
#  '61st_Academy_Awards',
#  '62nd_Academy_Awards',
#  '64th_Academy_Awards',
#  '66th_Academy_Awards',
#  '66th_Directors_Guild_of_America_Awards',
#  '68th_Academy_Awards',
#  '6th_Academy_Awards',
#  '73rd_Academy_Awards',
#  '75th_Academy_Awards',
#  '77th_Academy_Awards',
#  '79th_Academy_Awards',
#  '80th_Academy_Awards',
#  '81st_Academy_Awards',
#  '82nd_Academy_Awards',
#  '84th_Academy_Awards',
#  '86th_Academy_Awards',
#  '8th_Academy_Awards',
#  'ARY_Film_Awards',
#  'Academy_Award_for_Best_Adapted_Screenplay',
#  'Academy_Award_for_Best_Animated_Feature',
#  'Academy_Award_for_Best_Documentary_(Short_Subject)',
#  'Academy_Award_for_Best_Documentary_Feature',
#  'Academy_Award_for_Best_Foreign_Language_Film',
#  'Academy_Award_for_Best_Makeup_and_Hairstyling',
#  'Academy_Award_for_Best_Original_Musical',
#  'Academy_Award_for_Best_Original_Score',
#  'Academy_Award_for_Best_Original_Screenplay',
#  'Academy_Award_for_Best_Picture',
#  'Academy_Award_for_Best_Production_Design',
#  'Academy_Award_for_Best_Sound_Editing',
#  'Academy_Award_for_Technical_Achievement',
#  'Academy_Scientific_and_Technical_Award',
#  'Adam_&_Eve_(company)',
#  'Alejandro_González_Iñárritu',
#  'Amanda_Award',
#  'Ambassador_Hotel_(Los_Angeles)',
#  'American_Broadcasting_Company',
#  'American_Sniper',
#  'American_Sniper_(film)',
#  'Argentine_Film_Critics_Association',
#  'Batavia,_Illinois',
#  'Best_Actor',
#  'Best_Actress',
#  'Bette_Davis',
#  'Big_Hero_6',
#  'Birdman_of_Alcatraz_(film)',
#  'Black_tie',
#  'Boy',
#  'Boyhood_(film)',
#  'Bradley_Cooper',
#  'Britannia_metal',
#  'British_Academy_Film_Awards',
#  'C.W._Shumway_&_Sons',
#  'Cannes_Film_Festival',
#  'Charlie_Chaplin',
#  'Cinema_of_the_United_States',
#  'Citizen_Kane',
#  'Citizenfour',
#  'Crash_(2004_film)',
#  'Crusades',
#  'Digital_cinema',
#  'Dolby_Laboratories',
#  'Dolby_Theatre',
#  'Dolores_del_Río',
#  'Dorothy_Chandler_Pavilion',
#  'Dudley_Nichols',
#  'Easter',
#  'Eastman_Kodak',
#  'Elton_John_AIDS_Foundation_Academy_Award_Party',
#  'Emil_Jannings',
#  'Emilio_Fernández',
#  'Emmy_Award',
#  'FAMAS_Award',
#  'Film_Independent_Spirit_Awards',
#  'Film_awards_seasons',
#  'For_Your_Consideration_(advertising)',
#  'George_Stanley_(sculptor)',
#  'Golden_Horse_Film_Festival_and_Awards',
#  'Governors_Awards',
#  'Hollywood_Bowl',
#  'Hollywood_Roosevelt_Hotel',
#  'Ida',
#  'Instant-runoff_voting',
#  'Internal_Revenue_Service',
#  'Irving_G._Thalberg_Memorial_Award',
#  'Japan_Academy_Prize_(film)',
#  'Jean_Hersholt_Humanitarian_Award',
#  'John_Salley',
#  'Judith_Hoag',
#  'Julie_Andrews',
#  'Kate_Linder',
#  'Leonardo_DiCaprio',
#  'List_of_Academy_Award-winning_films',
#  'List_of_Academy_Award-winning_foreign-language_films',
#  'List_of_Academy_Award_records',
#  'List_of_Asian_Academy_Award_winners_and_nominees',
#  'List_of_Australian_Academy_Award_winners_and_nominees',
#  'List_of_Best_Actor_winners_by_age',
#  'List_of_Best_Actress_winners_by_age',
#  'List_of_Best_Picture_milestones',
#  'List_of_Best_Supporting_Actor_winners_by_age',
#  'List_of_Best_Supporting_Actress_winners_by_age',
#  'List_of_Brazilian_Academy_Award_winners_and_nominees',
#  'List_of_English_Academy_Award_nominees_and_winners',
#  'List_of_French_Academy_Award_winners_and_nominees',
#  'List_of_Italian_Academy_Award_winners_and_nominees',
#  'List_of_New_Zealand_Academy_Award_winners_and_nominees',
#  'List_of_Spanish_Academy_Award_winners_and_nominees',
#  "List_of_actors_who_won_the_Academy,_BAFTA,_Golden_Globe,_SAG,_and_Critic's_Choice_Award_for_a_single_performance",
#  'List_of_actors_with_two_or_more_Academy_Award_nominations_in_acting_categories',
#  'List_of_cinema_and_movie_theater_chains',
#  'List_of_film_awards',
#  'List_of_films_with_all_four_Academy_Award_acting_nominations',
#  'List_of_films_with_the_most_Oscars_per_ceremony',
#  'List_of_foreign-language_films_nominated_for_Academy_Awards',
#  'List_of_highest-grossing_films',
#  'List_of_nominees_for_the_Academy_Award_for_Best_Actor_(by_actor)',
#  'List_of_nominees_for_the_Academy_Award_for_Best_Actress_(by_actress)',
#  'List_of_nominees_for_the_Academy_Award_for_Best_Supporting_Actor_(by_actor)',
#  'List_of_nominees_for_the_Academy_Award_for_Best_Supporting_Actress_(by_actress)',
#  'List_of_oldest_and_youngest_Academy_Award_winners_and_nominees',
#  'List_of_superlative_Academy_Award_winners_and_nominees',
#  'List_of_years_in_film',
#  'Los_Angeles_County,_California',
#  'Los_Angeles_Music_Center',
#  'Lumières_Award',
#  'Margaret_Herrick',
#  'Marlon_Brando',
#  'Melrose_Avenue',
#  'Michael_Keaton',
#  'Midnight_Cowboy',
#  'Mike_Todd',
#  'Millennium_Biltmore_Hotel',
#  "NCAA_Men's_Division_I_Basketball_Tournament",
#  'National_Basketball_Association',
#  'National_Football_League',
#  'Orson_Welles',
#  'Oscar',
#  'Oscar_love_curse',
#  'Oscar_season',
#  'Pacific_Design_Center',
#  'Pantages_Theatre_(Hollywood)',
#  'Patton_(film)',
#  'Popularity_contest',
#  'Producers_Guild_of_America_Award',
#  'Santa_Monica,_California',
#  'Santa_Monica_Civic_Auditorium',
#  'Selma',
#  'Selma_(film)',
#  'Seth_Rogen',
#  'Sochi',
#  'Special_Achievement_Academy_Award',
#  'Sunset_Tower',
#  'Super_Bowl',
#  'The_Godfather',
#  'The_Grand_Budapest_Hotel',
#  'The_Hurt_Locker',
#  'The_Lego_Movie',
#  'The_Lord_of_the_Rings:_The_Return_of_the_King',
#  'The_Oscar_(film)',
#  'The_Way_of_All_Flesh_(film)',
#  'Tony_Award',
#  'Trophy',
#  'Venice_Film_Festival',
#  'Whiplash',
#  'Whiplash_(2014_film)',
#  'William_Friedkin',
#  'Wilshire_Boulevard',
#  'Writers_Guild_of_America_Awards_2014',
#  '10th_Academy_Awards',
#  '12th_Academy_Awards',
#  '14th_Academy_Awards',
#  '16th_Academy_Awards',
#  '1985_Academy_Awards',
#  '1990_Academy_Awards',
#  '1998_Academy_Awards',
#  '2001_Academy_Awards',
#  '2007_Academy_Awards',
#  '2009_Academy_Awards',
#  '2010_Academy_Awards',
#  '2014_Academy_Awards',
#  '2015_in_film',
#  '23rd_Academy_Awards',
#  '25th_Academy_Awards',
#  '27th_Academy_Awards',
#  '29th_Academy_Awards',
#  '30th_Academy_Awards',
#  '31st_Academy_Awards',
#  '32nd_Academy_Awards',
#  '34th_Academy_Awards',
#  '36th_Academy_Awards',
#  '38th_Academy_Awards',
#  '3rd_Academy_Awards',
#  '43rd_Academy_Awards',
#  '45th_Academy_Awards',
#  '47th_Academy_Awards',
#  '49th_Academy_Awards',
#  '50th_Academy_Awards',
#  '51st_Academy_Awards',
#  '52nd_Academy_Awards',
#  '54th_Academy_Awards',
#  '56th_Academy_Awards',
#  '58th_Academy_Awards',
#  '5th_Academy_Awards',
#  '63rd_Academy_Awards',
#  '65th_Academy_Awards',
#  '67th_Academy_Awards',
#  '69th_Academy_Awards',
#  '70_mm_film',
#  '70th_Academy_Awards',
#  '71st_Academy_Awards',
#  '720p',
#  '72nd_Academy_Awards',
#  '74th_Academy_Awards',
#  '76th_Academy_Awards',
#  '78th_Academy_Awards',
#  '7th_Academy_Awards',
#  '83rd_Academy_Awards',
#  '85th_Academy_Awards',
#  '87th_Academy_Awards',
#  'AACTA_Awards',
#  'AMC_(TV_channel)',
#  'Academy_Award_for_Best_Actor',
#  'Academy_Award_for_Best_Actress',
#  'Academy_Award_for_Best_Animated_Short_Film',
#  'Academy_Award_for_Best_Assistant_Director',
#  'Academy_Award_for_Best_Cinematography',
#  'Academy_Award_for_Best_Costume_Design',
#  'Academy_Award_for_Best_Dance_Direction',
#  'Academy_Award_for_Best_Directing',
#  'Academy_Award_for_Best_Film_Editing',
#  'Academy_Award_for_Best_Live_Action_Short_Film',
#  'Academy_Award_for_Best_Original_Song',
#  'Academy_Award_for_Best_Sound',
#  'Academy_Award_for_Best_Story',
#  'Academy_Award_for_Best_Supporting_Actor',
#  'Academy_Award_for_Best_Supporting_Actress',
#  'Academy_Award_for_Best_Visual_Effects',
#  'Academy_Awards',
#  'Academy_Awards_pre-show',
#  'Academy_Honorary_Award',
#  'Academy_Juvenile_Award',
#  'Academy_of_Motion_Picture_Arts_and_Sciences',
#  'Africa_Movie_Academy_Awards',
#  'Alaska',
#  'Argentine_Academy_of_Cinematography_Arts_and_Sciences',
#  'Ariel_Award',
#  'Art_Deco',
#  'Attempted_assassination_of_Ronald_Reagan',
#  'B_movie',
#  'Benedict_Cumberbatch',
#  'Berlin_International_Film_Festival',
#  'Best_Picture',
#  'Birdman',
#  'Birdman_(film)',
#  'Bow_tie',
#  'Brad_Pitt',
#  'British_Academy_of_Film_and_Television_Arts',
#  'Broadcast_delay',
#  'Canadian_Screen_Awards',
#  'Carolyn_Hennesy',
#  'Cedric_Gibbons',
#  'Chris_Mulkey',
#  'Clint_Eastwood',
#  "Critics'_Choice_Movie_Award",
#  'César_Award',
#  'Daniel_Day-Lewis',
#  'David_di_Donatello',
#  'Deutscher_Filmpreis',
#  'Eddie_Redmayne',
#  'Fifty_Shades_of_Grey',
#  'Fifty_Shades_of_Grey_(film)',
#  'Film_industry',
#  'Filmfare_Awards',
#  'Filmsite.org',
#  'George_C._Scott',
#  'Glen_Campbell',
#  'Golden_Globe_Award',
#  'Golden_Raspberry_Awards',
#  'Gordon_E._Sawyer_Award',
#  'Goya_Awards',
#  'Grammy_Award',
#  'Grande_Prêmio_do_Cinema_Brasileiro',
#  'Guldbagge_Awards',
#  'Harold_Russell',
#  'History_of_film',
#  'Hollywood',
#  'Hong_Kong_Film_Award',
#  'Interstellar',
#  'Interstellar_(film)',
#  'J._K._Simmons',
#  'Janet_Gaynor',
#  'Jennifer_Lawrence',
#  "Jim_O'Heir",
#  'John_A._Bonner_Medal_of_Commendation',
#  'Julianne_Moore',
#  'Lady_Gaga',
#  'List_of_Academy_Award-winning_families',
#  'List_of_Academy_Award_for_Best_Directing_winners_by_age',
#  'List_of_Academy_Award_trophies_on_public_display',
#  'List_of_Academy_Awards_ceremonies',
#  'List_of_Big_Five_Academy_Award_winners_and_nominees',
#  'List_of_Indian_Academy_Award_winners_and_nominees',
#  'List_of_Latin_American_Academy_Award_winners_and_nominees',
#  'List_of_Mexican_Academy_Award_winners_and_nominees',
#  'List_of_Nordic_Academy_Award_winners_and_nominees',
#  'List_of_Polish_Academy_Award_winners_and_nominees',
#  'List_of_actors_nominated_for_Academy_Awards_for_foreign_language_performances',
#  'List_of_actors_nominated_for_two_Academy_Awards_in_the_same_year',
#  'List_of_actors_who_have_appeared_in_multiple_Best_Picture_Academy_Award_winners',
#  'List_of_actors_with_two_or_more_Academy_Awards_in_acting_categories',
#  'List_of_awards_for_supporting_actor',
#  'List_of_black_Academy_Award_winners_and_nominees',
#  'List_of_countries_by_number_of_Academy_Awards_for_Best_Foreign_Language_Film',
#  'List_of_directors_with_two_or_more_Academy_Awards_for_Best_Directing',
#  'List_of_fictitious_Academy_Award_winners_and_nominees',
#  'List_of_people_who_have_won_Academy,_Emmy,_Grammy,_and_Tony_Awards',
#  'List_of_people_who_have_won_multiple_Academy_Awards_in_a_single_year',
#  'List_of_posthumous_Academy_Award_winners_and_nominees',
#  'List_of_presenters_of_Best_Picture_Academy_Award',
#  'Lists_of_Hispanic_Academy_Award_winners_and_nominees_by_country',
#  'Los_Angeles_Times',
#  'Magritte_Award',
#  'Main_Page',
#  'Majestic_Theatre_(Columbus_Circle)',
#  'Martin_Luther_King_Jr.',
#  'Meryl_Streep',
#  'Metro-Goldwyn-Mayer',
#  'Motion_Picture_&_Television_Fund',
#  'NBC',
#  'National_Film_Awards_(India)',
#  'Neil_Patrick_Harris',
#  'New_Century_Theatre',
#  'Nielsen_ratings',
#  'No_Country_for_Old_Men_(film)',
#  'Nobel_Prize',
#  'Oscar_bait',
#  'Oscar_speech',
#  'Patricia_Arquette',
#  'PricewaterhouseCoopers',
#  'Producers_Guild_of_America_Awards_2014',
#  'Progressive_scan',
#  'Purple_Rain_(film)',
#  'R.S._Owens_&_Company',
#  'RMS_Titanic',
#  'Robin_Williams',
#  'Ronald_Reagan',
#  'Sacheen_Littlefeather',
#  'San_Sebastián_International_Film_Festival',
#  'Scorpion_(TV_series)',
#  'Screen_Actors_Guild_Award',
#  'Sean_Penn',
#  'Shrine_Auditorium',
#  'Single_transferable_vote',
#  'Stephen_Hawking',
#  'Steven_Spielberg',
#  'Student_Academy_Awards',
#  'TCL_Chinese_Theatre',
#  'The_Beverly_Hills_Hotel',
#  'The_Imitation_Game',
#  'The_Informer_(1935_film)',
#  'The_Last_Command_(1928_film)',
#  'The_Theory_of_Everything_(2014_film)',
#  'Time_(magazine)',
#  'Tin',
#  'Titanic_(1997_film)',
#  'Videophone',
#  'Vince_Lombardi_Trophy',
#  'Walt_Disney',
#  'Winter_Olympic_Games',
#  'Writers_Guild_of_America_Award']
